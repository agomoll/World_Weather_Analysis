# %%
# 1. Create a folder called Weather_Database.
# 2. Create a new Jupyter Notebook file to retrieve the weather data, and name it Weather_Database.ipynb.
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import time
from datetime import datetime

# %%
# 3. Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.
cities =[]

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# 5. Perform an API call with the OpenWeatherMap.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a72fe0cbaab6663ac9bc09242e81fe75

# %%
# 6. Create an empty list to hold the weather data and retrieve the infomation of interest.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
            
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add one to the record count
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | araouane
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | constitucion
# Processing Record 5 of Set 1 | itacoatiara
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | caravelas
# Processing Record 8 of Set 1 | son la
# Processing Record 9 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | mao
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bhavnagar
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | boleslawiec
# Processing Record 19 of Set 1 | lompoc
# Processing Record 20 of Set 1 | antalaha
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | namwala
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | ahipara
# Processing Record 31 of Set 1 | salalah
# Processing Record 32 of Set 1 | koutsouras
# Processing Record 33 of Set 1 | necochea
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | den helder
# Processing Record 37 of Set 1 | oktyabrskoye
# Processing Record 38 of Set 1 | guiratinga
# Processing Record 39 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 1 | walvis bay
# Processing Record 41 of Set 1 | sao filipe
# Processing Record 42 of Set 1 | boyuibe
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | volga
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | pulandian
# Processing Record 47 of Set 1 | the valley
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | terrace
# Processing Record 50 of Set 1 | boyolangu
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | hami
# Processing Record 3 of Set 2 | abbeville
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | ossora
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | itarema
# Processing Record 10 of Set 2 | geraldton
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | flinders
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | daru
# Processing Record 16 of Set 2 | prince rupert
# Processing Record 17 of Set 2 | xicotencatl
# Processing Record 18 of Set 2 | aliaga
# Processing Record 19 of Set 2 | havre-saint-pierre
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | saint-pierre
# Processing Record 23 of Set 2 | jutai
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | severo-kurilsk
# Processing Record 26 of Set 2 | zyryanka
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | luganville
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | seoul
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | stornoway
# Processing Record 36 of Set 2 | bemidji
# Processing Record 37 of Set 2 | galveston
# Processing Record 38 of Set 2 | samarai
# Processing Record 39 of Set 2 | namibe
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 2 | tarbolton
# Processing Record 43 of Set 2 | ballina
# Processing Record 44 of Set 2 | marshall
# Processing Record 45 of Set 2 | beringovskiy
# Processing Record 46 of Set 2 | kinsale
# Processing Record 47 of Set 2 | omboue
# Processing Record 48 of Set 2 | mutis
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | iqaluit
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 3 | flin flon
# Processing Record 5 of Set 3 | ayagoz
# Processing Record 6 of Set 3 | nanakuli
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | pizarro
# Processing Record 9 of Set 3 | vestmanna
# Processing Record 10 of Set 3 | timmins
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | asau
# Processing Record 13 of Set 3 | seymchan
# Processing Record 14 of Set 3 | qazanbulaq
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | ikalamavony
# Processing Record 17 of Set 3 | cururupu
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | sulurpeta
# City not found. Skipping...
# Processing Record 25 of Set 3 | huilong
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | margate
# Processing Record 28 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | aosta
# Processing Record 30 of Set 3 | vanimo
# Processing Record 31 of Set 3 | lamu
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | varhaug
# Processing Record 34 of Set 3 | nantucket
# Processing Record 35 of Set 3 | lindi
# Processing Record 36 of Set 3 | zyryanskoye
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | bonthe
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | pinheiro machado
# Processing Record 41 of Set 3 | ribeira grande
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 3 | carballo
# Processing Record 45 of Set 3 | ginir
# Processing Record 46 of Set 3 | fuerte olimpo
# Processing Record 47 of Set 3 | nuqui
# Processing Record 48 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 3 | amiens
# Processing Record 50 of Set 3 | mujiayingzi
# Processing Record 1 of Set 4 | arona
# Processing Record 2 of Set 4 | dodge city
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | avarua
# Processing Record 6 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | luderitz
# Processing Record 9 of Set 4 | liku
# Processing Record 10 of Set 4 | harper
# Processing Record 11 of Set 4 | praia da vitoria
# Processing Record 12 of Set 4 | kupang
# Processing Record 13 of Set 4 | octeville
# Processing Record 14 of Set 4 | crnici
# Processing Record 15 of Set 4 | alice springs
# Processing Record 16 of Set 4 | port alfred
# Processing Record 17 of Set 4 | beyneu
# Processing Record 18 of Set 4 | karabulak
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 4 | bousse
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | manadhoo
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | tiznit
# Processing Record 26 of Set 4 | ust-ilimsk
# Processing Record 27 of Set 4 | mackay
# Processing Record 28 of Set 4 | kaitangata
# Processing Record 29 of Set 4 | matay
# Processing Record 30 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 4 | fujinomiya
# Processing Record 32 of Set 4 | bambous virieux
# Processing Record 33 of Set 4 | te anau
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | roma
# Processing Record 36 of Set 4 | ostrovnoy
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | isangel
# Processing Record 39 of Set 4 | kenora
# Processing Record 40 of Set 4 | samana
# Processing Record 41 of Set 4 | bengkalis
# City not found. Skipping...
# Processing Record 42 of Set 4 | coihaique
# Processing Record 43 of Set 4 | tiarei
# Processing Record 44 of Set 4 | muravlenko
# Processing Record 45 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 4 | portland
# Processing Record 47 of Set 4 | sao desiderio
# Processing Record 48 of Set 4 | pangkalanbuun
# Processing Record 49 of Set 4 | miyako
# Processing Record 50 of Set 4 | port macquarie
# Processing Record 1 of Set 5 | pilar
# Processing Record 2 of Set 5 | polessk
# Processing Record 3 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 5 | broome
# Processing Record 5 of Set 5 | san patricio
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | bosaso
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | balabac
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | dorogino
# Processing Record 13 of Set 5 | souillac
# Processing Record 14 of Set 5 | verkhnevilyuysk
# Processing Record 15 of Set 5 | ilanskiy
# Processing Record 16 of Set 5 | vila franca do campo
# Processing Record 17 of Set 5 | kuching
# Processing Record 18 of Set 5 | saldanha
# Processing Record 19 of Set 5 | alyangula
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | port keats
# Processing Record 23 of Set 5 | morondava
# Processing Record 24 of Set 5 | lata
# Processing Record 25 of Set 5 | hualmay
# Processing Record 26 of Set 5 | tiksi
# Processing Record 27 of Set 5 | bathsheba
# Processing Record 28 of Set 5 | bayanday
# Processing Record 29 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 30 of Set 5 | bredasdorp
# Processing Record 31 of Set 5 | xiangxiang
# Processing Record 32 of Set 5 | mercedes
# Processing Record 33 of Set 5 | cabedelo
# Processing Record 34 of Set 5 | berlevag
# Processing Record 35 of Set 5 | thinadhoo
# Processing Record 36 of Set 5 | palauig
# Processing Record 37 of Set 5 | opuwo
# Processing Record 38 of Set 5 | miri
# Processing Record 39 of Set 5 | tautira
# Processing Record 40 of Set 5 | vila
# Processing Record 41 of Set 5 | jalu
# Processing Record 42 of Set 5 | jumla
# Processing Record 43 of Set 5 | magole
# Processing Record 44 of Set 5 | yellowknife
# Processing Record 45 of Set 5 | cootamundra
# Processing Record 46 of Set 5 | fayaoue
# Processing Record 47 of Set 5 | mayumba
# Processing Record 48 of Set 5 | comodoro rivadavia
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | turukhansk
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | darhan
# Processing Record 3 of Set 6 | cidreira
# Processing Record 4 of Set 6 | torrevieja
# Processing Record 5 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 6 | price
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | malakal
# Processing Record 9 of Set 6 | ixtapa
# Processing Record 10 of Set 6 | carson city
# Processing Record 11 of Set 6 | provideniya
# Processing Record 12 of Set 6 | sao joao da barra
# Processing Record 13 of Set 6 | tiradentes
# Processing Record 14 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 6 | mabaruma
# Processing Record 16 of Set 6 | faanui
# Processing Record 17 of Set 6 | rocha
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | anaconda
# Processing Record 20 of Set 6 | oliver
# Processing Record 21 of Set 6 | svetlyy
# Processing Record 22 of Set 6 | tilichiki
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | clyde river
# Processing Record 25 of Set 6 | bilibino
# Processing Record 26 of Set 6 | podgornoye
# Processing Record 27 of Set 6 | arman
# Processing Record 28 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 6 | taoudenni
# Processing Record 30 of Set 6 | olafsvik
# Processing Record 31 of Set 6 | ishigaki
# Processing Record 32 of Set 6 | hervey bay
# Processing Record 33 of Set 6 | garowe
# Processing Record 34 of Set 6 | upernavik
# Processing Record 35 of Set 6 | isla mujeres
# Processing Record 36 of Set 6 | northam
# Processing Record 37 of Set 6 | acapulco
# Processing Record 38 of Set 6 | roanoke rapids
# Processing Record 39 of Set 6 | kattivakkam
# Processing Record 40 of Set 6 | gouvieux
# Processing Record 41 of Set 6 | simao
# Processing Record 42 of Set 6 | dunedin
# Processing Record 43 of Set 6 | bandarbeyla
# Processing Record 44 of Set 6 | sijunjung
# Processing Record 45 of Set 6 | nome
# Processing Record 46 of Set 6 | shimanovsk
# Processing Record 47 of Set 6 | casteltermini
# Processing Record 48 of Set 6 | talnakh
# Processing Record 49 of Set 6 | inhambane
# Processing Record 50 of Set 6 | nhulunbuy
# Processing Record 1 of Set 7 | holme
# Processing Record 2 of Set 7 | tecolutla
# Processing Record 3 of Set 7 | yefremov
# Processing Record 4 of Set 7 | katsuura
# Processing Record 5 of Set 7 | brae
# Processing Record 6 of Set 7 | sibolga
# Processing Record 7 of Set 7 | baiyin
# Processing Record 8 of Set 7 | brand-erbisdorf
# Processing Record 9 of Set 7 | okha
# Processing Record 10 of Set 7 | olga
# Processing Record 11 of Set 7 | carnarvon
# Processing Record 12 of Set 7 | eureka
# Processing Record 13 of Set 7 | burica
# City not found. Skipping...
# Processing Record 14 of Set 7 | chumikan
# Processing Record 15 of Set 7 | kodiak
# Processing Record 16 of Set 7 | valparaiso
# Processing Record 17 of Set 7 | waipawa
# Processing Record 18 of Set 7 | saint-georges
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | vaovai
# City not found. Skipping...
# Processing Record 22 of Set 7 | nalut
# Processing Record 23 of Set 7 | emerald
# Processing Record 24 of Set 7 | matagami
# Processing Record 25 of Set 7 | general roca
# Processing Record 26 of Set 7 | marquette
# Processing Record 27 of Set 7 | steamboat springs
# Processing Record 28 of Set 7 | provins
# Processing Record 29 of Set 7 | mbandaka
# Processing Record 30 of Set 7 | puerto quijarro
# Processing Record 31 of Set 7 | presidencia roque saenz pena
# Processing Record 32 of Set 7 | puntarenas
# Processing Record 33 of Set 7 | cap malheureux
# Processing Record 34 of Set 7 | chicama
# Processing Record 35 of Set 7 | paamiut
# Processing Record 36 of Set 7 | makakilo city
# Processing Record 37 of Set 7 | panjab
# Processing Record 38 of Set 7 | coquimbo
# Processing Record 39 of Set 7 | rawson
# Processing Record 40 of Set 7 | sambava
# Processing Record 41 of Set 7 | gurdaspur
# City not found. Skipping...
# Processing Record 42 of Set 7 | azrow
# City not found. Skipping...
# Processing Record 43 of Set 7 | pinega
# Processing Record 44 of Set 7 | zhangye
# Processing Record 45 of Set 7 | bogorodskoye
# Processing Record 46 of Set 7 | halifax
# Processing Record 47 of Set 7 | providencia
# Processing Record 48 of Set 7 | dawlatabad
# Processing Record 49 of Set 7 | pa sang
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | ondjiva
# Processing Record 3 of Set 8 | ganzhou
# Processing Record 4 of Set 8 | pietersburg
# Processing Record 5 of Set 8 | guarapari
# Processing Record 6 of Set 8 | belmonte
# Processing Record 7 of Set 8 | japura
# Processing Record 8 of Set 8 | henties bay
# Processing Record 9 of Set 8 | dongsheng
# Processing Record 10 of Set 8 | ust-maya
# Processing Record 11 of Set 8 | xiamen
# Processing Record 12 of Set 8 | mount isa
# Processing Record 13 of Set 8 | rabo de peixe
# Processing Record 14 of Set 8 | manado
# Processing Record 15 of Set 8 | payo
# Processing Record 16 of Set 8 | hurricane
# Processing Record 17 of Set 8 | shubarkuduk
# Processing Record 18 of Set 8 | anchorage
# Processing Record 19 of Set 8 | kavaratti
# Processing Record 20 of Set 8 | luorong
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | nishihara
# Processing Record 23 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 8 | vorontsovka
# Processing Record 25 of Set 8 | talcahuano
# Processing Record 26 of Set 8 | kurayoshi
# Processing Record 27 of Set 8 | kristiansund
# Processing Record 28 of Set 8 | pimenta bueno
# Processing Record 29 of Set 8 | acarau
# Processing Record 30 of Set 8 | zagan
# Processing Record 31 of Set 8 | lagoa
# Processing Record 32 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 8 | scarborough
# Processing Record 34 of Set 8 | sur
# Processing Record 35 of Set 8 | sechura
# Processing Record 36 of Set 8 | hambantota
# Processing Record 37 of Set 8 | enshi
# Processing Record 38 of Set 8 | kidal
# Processing Record 39 of Set 8 | serrana
# Processing Record 40 of Set 8 | campo maior
# Processing Record 41 of Set 8 | sidi ali
# Processing Record 42 of Set 8 | yulara
# Processing Record 43 of Set 8 | huarmey
# Processing Record 44 of Set 8 | dire dawa
# Processing Record 45 of Set 8 | nouadhibou
# Processing Record 46 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 8 | san policarpo
# Processing Record 48 of Set 8 | suksun
# Processing Record 49 of Set 8 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 8 | fernie
# Processing Record 1 of Set 9 | nizhniy kuranakh
# Processing Record 2 of Set 9 | fare
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | san carlos
# Processing Record 5 of Set 9 | pisco
# Processing Record 6 of Set 9 | san cristobal
# Processing Record 7 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 9 | shihezi
# Processing Record 9 of Set 9 | tarogong
# Processing Record 10 of Set 9 | honiara
# Processing Record 11 of Set 9 | cabo san lucas
# Processing Record 12 of Set 9 | bireun
# Processing Record 13 of Set 9 | kenai
# Processing Record 14 of Set 9 | ghanzi
# Processing Record 15 of Set 9 | pallisa
# Processing Record 16 of Set 9 | hofn
# Processing Record 17 of Set 9 | kismayo
# Processing Record 18 of Set 9 | gamba
# Processing Record 19 of Set 9 | ulaangom
# Processing Record 20 of Set 9 | yokadouma
# Processing Record 21 of Set 9 | port blair
# Processing Record 22 of Set 9 | kormilovka
# Processing Record 23 of Set 9 | egvekinot
# Processing Record 24 of Set 9 | bud
# Processing Record 25 of Set 9 | sinnamary
# Processing Record 26 of Set 9 | sao miguel do tapuio
# Processing Record 27 of Set 9 | nacozari
# Processing Record 28 of Set 9 | odweyne
# Processing Record 29 of Set 9 | port said
# Processing Record 30 of Set 9 | cabra
# Processing Record 31 of Set 9 | haines junction
# Processing Record 32 of Set 9 | ashland
# Processing Record 33 of Set 9 | prado
# Processing Record 34 of Set 9 | pringsewu
# Processing Record 35 of Set 9 | aswan
# Processing Record 36 of Set 9 | ust-omchug
# Processing Record 37 of Set 9 | fairbanks
# Processing Record 38 of Set 9 | ust-kut
# Processing Record 39 of Set 9 | goderich
# Processing Record 40 of Set 9 | laguna
# Processing Record 41 of Set 9 | kavieng
# Processing Record 42 of Set 9 | gladstone
# Processing Record 43 of Set 9 | kamenka
# Processing Record 44 of Set 9 | hornepayne
# Processing Record 45 of Set 9 | grindavik
# Processing Record 46 of Set 9 | tecoanapa
# Processing Record 47 of Set 9 | antofagasta
# Processing Record 48 of Set 9 | ambilobe
# Processing Record 49 of Set 9 | am timan
# Processing Record 50 of Set 9 | sola
# Processing Record 1 of Set 10 | siderno
# Processing Record 2 of Set 10 | vila velha
# Processing Record 3 of Set 10 | high level
# Processing Record 4 of Set 10 | tomatlan
# Processing Record 5 of Set 10 | kindu
# Processing Record 6 of Set 10 | pevek
# Processing Record 7 of Set 10 | abeche
# Processing Record 8 of Set 10 | san quintin
# Processing Record 9 of Set 10 | karak
# Processing Record 10 of Set 10 | abu samrah
# Processing Record 11 of Set 10 | cintalapa
# Processing Record 12 of Set 10 | chifeng
# Processing Record 13 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 10 | novi pazar
# Processing Record 15 of Set 10 | vardo
# Processing Record 16 of Set 10 | agadez
# Processing Record 17 of Set 10 | micheweni
# Processing Record 18 of Set 10 | lavrentiya
# Processing Record 19 of Set 10 | darab
# Processing Record 20 of Set 10 | anadyr
# Processing Record 21 of Set 10 | erdenet
# Processing Record 22 of Set 10 | mantenopolis
# Processing Record 23 of Set 10 | huntsville
# Processing Record 24 of Set 10 | porto walter
# Processing Record 25 of Set 10 | florianopolis
# Processing Record 26 of Set 10 | shunyi
# Processing Record 27 of Set 10 | quatre cocos
# Processing Record 28 of Set 10 | manta
# Processing Record 29 of Set 10 | inuvik
# Processing Record 30 of Set 10 | keshorai patan
# Processing Record 31 of Set 10 | guanare
# Processing Record 32 of Set 10 | pacific grove
# Processing Record 33 of Set 10 | motygino
# Processing Record 34 of Set 10 | suffolk
# Processing Record 35 of Set 10 | shirokiy
# Processing Record 36 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 10 | batyrevo
# Processing Record 38 of Set 10 | latung
# Processing Record 39 of Set 10 | miramar
# Processing Record 40 of Set 10 | kuryk
# Processing Record 41 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 10 | milkovo
# Processing Record 43 of Set 10 | tyazhinskiy
# Processing Record 44 of Set 10 | la palma
# Processing Record 45 of Set 10 | mosquera
# Processing Record 46 of Set 10 | yining
# Processing Record 47 of Set 10 | valleyview
# Processing Record 48 of Set 10 | senador jose porfirio
# Processing Record 49 of Set 10 | sapozhok
# Processing Record 50 of Set 10 | wloszczowa
# Processing Record 1 of Set 11 | padang
# Processing Record 2 of Set 11 | yaan
# Processing Record 3 of Set 11 | banting
# Processing Record 4 of Set 11 | igrim
# Processing Record 5 of Set 11 | chapais
# Processing Record 6 of Set 11 | aasiaat
# Processing Record 7 of Set 11 | mezen
# Processing Record 8 of Set 11 | samarkand
# Processing Record 9 of Set 11 | morant bay
# Processing Record 10 of Set 11 | maldonado
# Processing Record 11 of Set 11 | sinaloa
# Processing Record 12 of Set 11 | the pas
# Processing Record 13 of Set 11 | mali
# Processing Record 14 of Set 11 | maragogi
# Processing Record 15 of Set 11 | puerto escondido
# Processing Record 16 of Set 11 | kurchum
# Processing Record 17 of Set 11 | avera
# Processing Record 18 of Set 11 | angoche
# Processing Record 19 of Set 11 | hwange
# Processing Record 20 of Set 11 | pangnirtung
# Processing Record 21 of Set 11 | irbil
# Processing Record 22 of Set 11 | gangtok
# Processing Record 23 of Set 11 | port hardy
# Processing Record 24 of Set 11 | andapa
# Processing Record 25 of Set 11 | nanortalik
# Processing Record 26 of Set 11 | la ronge
# Processing Record 27 of Set 11 | pembroke
# Processing Record 28 of Set 11 | kautokeino
# Processing Record 29 of Set 11 | minsk
# Processing Record 30 of Set 11 | alofi
# Processing Record 31 of Set 11 | sanok
# Processing Record 32 of Set 11 | port augusta
# Processing Record 33 of Set 11 | ravenna
# Processing Record 34 of Set 11 | suzaka
# Processing Record 35 of Set 11 | srednekolymsk
# Processing Record 36 of Set 11 | krasnorechenskiy
# Processing Record 37 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 38 of Set 11 | baruun-urt
# Processing Record 39 of Set 11 | bagdarin
# Processing Record 40 of Set 11 | tual
# Processing Record 41 of Set 11 | kirakira
# Processing Record 42 of Set 11 | forst
# Processing Record 43 of Set 11 | jacareacanga
# Processing Record 44 of Set 11 | uberaba
# Processing Record 45 of Set 11 | kasane
# Processing Record 46 of Set 11 | lucapa
# Processing Record 47 of Set 11 | bendigo
# Processing Record 48 of Set 11 | raudeberg
# Processing Record 49 of Set 11 | polunochnoye
# Processing Record 50 of Set 11 | sheridan
# Processing Record 1 of Set 12 | alakurtti
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | moose factory
# Processing Record 4 of Set 12 | aksu
# Processing Record 5 of Set 12 | pimentel
# Processing Record 6 of Set 12 | remontnoye
# Processing Record 7 of Set 12 | nyuksenitsa
# Processing Record 8 of Set 12 | nampula
# Processing Record 9 of Set 12 | kalaleh
# Processing Record 10 of Set 12 | hinton
# Processing Record 11 of Set 12 | paredon
# Processing Record 12 of Set 12 | peniche
# Processing Record 13 of Set 12 | nipawin
# Processing Record 14 of Set 12 | college
# Processing Record 15 of Set 12 | maneadero
# Processing Record 16 of Set 12 | mizdah
# Processing Record 17 of Set 12 | kahului
# Processing Record 18 of Set 12 | vuktyl
# Processing Record 19 of Set 12 | tondano
# Processing Record 20 of Set 12 | ibatiba
# Processing Record 21 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 12 | zawadzkie
# Processing Record 24 of Set 12 | sampit
# Processing Record 25 of Set 12 | sai buri
# Processing Record 26 of Set 12 | koslan
# Processing Record 27 of Set 12 | cockburn town
# Processing Record 28 of Set 12 | svetlogorsk
# Processing Record 29 of Set 12 | irtyshskiy
# Processing Record 30 of Set 12 | bar bigha
# Processing Record 31 of Set 12 | tyukalinsk
# Processing Record 32 of Set 12 | loikaw
# Processing Record 33 of Set 12 | bubaque
# Processing Record 34 of Set 12 | canto do buriti
# Processing Record 35 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 12 | tahe
# Processing Record 38 of Set 12 | port hedland
# Processing Record 39 of Set 12 | demmin
# Processing Record 40 of Set 12 | kartaly
# Processing Record 41 of Set 12 | maceio
# Processing Record 42 of Set 12 | kibondo
# Processing Record 43 of Set 12 | arlit
# Processing Record 44 of Set 12 | rockland
# Processing Record 45 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 12 | chute-aux-outardes
# Processing Record 47 of Set 12 | vasteras
# Processing Record 48 of Set 12 | arganil
# Processing Record 49 of Set 12 | kindberg
# Processing Record 50 of Set 12 | balikpapan
# Processing Record 1 of Set 13 | zheleznodorozhnyy
# Processing Record 2 of Set 13 | teresina
# Processing Record 3 of Set 13 | deputatskiy
# Processing Record 4 of Set 13 | san jeronimo
# Processing Record 5 of Set 13 | nioro
# Processing Record 6 of Set 13 | havoysund
# Processing Record 7 of Set 13 | kasama
# Processing Record 8 of Set 13 | mayo
# Processing Record 9 of Set 13 | muros
# Processing Record 10 of Set 13 | tolaga bay
# Processing Record 11 of Set 13 | banjar
# Processing Record 12 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 13 | tabou
# Processing Record 14 of Set 13 | arrecife
# Processing Record 15 of Set 13 | adre
# Processing Record 16 of Set 13 | viedma
# Processing Record 17 of Set 13 | aksha
# Processing Record 18 of Set 13 | kandrian
# Processing Record 19 of Set 13 | chernyshevskiy
# Processing Record 20 of Set 13 | ouadda
# Processing Record 21 of Set 13 | trairi
# Processing Record 22 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 23 of Set 13 | banda aceh
# Processing Record 24 of Set 13 | ucluelet
# Processing Record 25 of Set 13 | panaba
# Processing Record 26 of Set 13 | burhaniye
# Processing Record 27 of Set 13 | husavik
# Processing Record 28 of Set 13 | manyana
# Processing Record 29 of Set 13 | tura
# Processing Record 30 of Set 13 | marawi
# Processing Record 31 of Set 13 | chepareria
# Processing Record 32 of Set 13 | severnyy
# Processing Record 33 of Set 13 | lugo
# Processing Record 34 of Set 13 | clermont
# Processing Record 35 of Set 13 | moron
# Processing Record 36 of Set 13 | ozinki
# Processing Record 37 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 38 of Set 13 | rawah
# Processing Record 39 of Set 13 | touros
# Processing Record 40 of Set 13 | ancud
# Processing Record 41 of Set 13 | yumen
# Processing Record 42 of Set 13 | umba
# Processing Record 43 of Set 13 | bauchi
# Processing Record 44 of Set 13 | sao miguel do araguaia
# Processing Record 45 of Set 13 | farah
# Processing Record 46 of Set 13 | venado tuerto
# Processing Record 47 of Set 13 | gulf gate estates
# Processing Record 48 of Set 13 | maraa
# Processing Record 49 of Set 13 | pitimbu
# Processing Record 50 of Set 13 | kargopol
# Processing Record 1 of Set 14 | renfrew
# Processing Record 2 of Set 14 | russell
# Processing Record 3 of Set 14 | newport
# Processing Record 4 of Set 14 | port-cartier
# Processing Record 5 of Set 14 | homer
# Processing Record 6 of Set 14 | bonavista
# Processing Record 7 of Set 14 | darnah
# Processing Record 8 of Set 14 | tubuala
# Processing Record 9 of Set 14 | grande prairie
# Processing Record 10 of Set 14 | rovaniemi
# Processing Record 11 of Set 14 | korla
# Processing Record 12 of Set 14 | komarno
# Processing Record 13 of Set 14 | agua dulce
# Processing Record 14 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record 15 of Set 14 | shadrinsk
# Processing Record 16 of Set 14 | altay
# Processing Record 17 of Set 14 | santiago de las vegas
# Processing Record 18 of Set 14 | emba
# Processing Record 19 of Set 14 | yevpatoriya
# Processing Record 20 of Set 14 | hokitika
# Processing Record 21 of Set 14 | wiwili
# Processing Record 22 of Set 14 | finschhafen
# Processing Record 23 of Set 14 | tazovskiy
# Processing Record 24 of Set 14 | malindi
# Processing Record 25 of Set 14 | kanniyakumari
# Processing Record 26 of Set 14 | kamaishi
# Processing Record 27 of Set 14 | abu dhabi
# Processing Record 28 of Set 14 | hashtrud
# Processing Record 29 of Set 14 | mulanje
# Processing Record 30 of Set 14 | podyuga
# Processing Record 31 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 32 of Set 14 | brazzaville
# Processing Record 33 of Set 14 | bumba
# Processing Record 34 of Set 14 | dothan
# Processing Record 35 of Set 14 | ornskoldsvik
# Processing Record 36 of Set 14 | visnes
# Processing Record 37 of Set 14 | lichinga
# Processing Record 38 of Set 14 | saraza
# Processing Record 39 of Set 14 | fazalpur
# Processing Record 40 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 14 | bhadrachalam
# Processing Record 42 of Set 14 | great yarmouth
# Processing Record 43 of Set 14 | cordenons
# Processing Record 44 of Set 14 | saint-augustin
# Processing Record 45 of Set 14 | lokosovo
# Processing Record 46 of Set 14 | los llanos de aridane
# Processing Record 47 of Set 14 | labuhan
# Processing Record 48 of Set 14 | yasugi
# Processing Record 49 of Set 14 | solnechnyy
# Processing Record 50 of Set 14 | bati
# Processing Record 1 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 15 | wad rawah
# Processing Record 3 of Set 15 | leh
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | lalsot
# Processing Record 6 of Set 15 | tando muhammad khan
# Processing Record 7 of Set 15 | san rafael
# Processing Record 8 of Set 15 | dryden
# Processing Record 9 of Set 15 | gadwal
# Processing Record 10 of Set 15 | guilford
# Processing Record 11 of Set 15 | villa carlos paz
# Processing Record 12 of Set 15 | nandikotkur
# Processing Record 13 of Set 15 | acajutla
# Processing Record 14 of Set 15 | shu
# Processing Record 15 of Set 15 | maymanak
# City not found. Skipping...
# Processing Record 16 of Set 15 | gasa
# Processing Record 17 of Set 15 | turdas
# Processing Record 18 of Set 15 | luwuk
# Processing Record 19 of Set 15 | ponta delgada
# Processing Record 20 of Set 15 | gold coast
# Processing Record 21 of Set 15 | santo antonio da platina
# Processing Record 22 of Set 15 | morehead
# Processing Record 23 of Set 15 | oktyabrskiy
# Processing Record 24 of Set 15 | palmer
# Processing Record 25 of Set 15 | ricaurte
# Processing Record 26 of Set 15 | san andres
# Processing Record 27 of Set 15 | sassandra
# Processing Record 28 of Set 15 | dongli
# Processing Record 29 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 15 | richards bay
# Processing Record 31 of Set 15 | santiago del estero
# Processing Record 32 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 33 of Set 15 | hefei
# Processing Record 34 of Set 15 | shimoda
# Processing Record 35 of Set 15 | sile
# Processing Record 36 of Set 15 | yerbogachen
# Processing Record 37 of Set 15 | orlik
# Processing Record 38 of Set 15 | estevan
# Processing Record 39 of Set 15 | ukiah
# Processing Record 40 of Set 15 | chitrakonda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Araouane      ML  18.9048   -3.5265     92.41         8          12
# 1     Saskylakh      RU  71.9167  114.0833      0.36        95         100
# 2       Mataura      NZ -46.1927  168.8643     55.54        97         100
# 3  Constitucion      CL -35.3333  -72.4167     64.44        57           0
# 4   Itacoatiara      BR  -3.1431  -58.4442     80.20        87         100
# 5    Georgetown      MY   5.4112  100.3354     83.95        87          40
# 6     Caravelas      BR -17.7125  -39.2481     83.07        66          78
# 7        Son La      VN  21.3167  103.9000     62.26        95          95
# 8         Bluff      NZ -46.6000  168.3333     59.50        81         100
# 9        Dikson      RU  73.5069   80.5464    -15.21       100          90
#
#    Wind Speed Current Description
# 0        9.73          few clouds
# 1       11.77     overcast clouds
# 2        0.89     overcast clouds
# 3       16.64           clear sky
# 4        3.44          light rain
# 5        2.30    scattered clouds
# 6        8.43       broken clouds
# 7        3.40     overcast clouds
# 8        4.29     overcast clouds
# 9        3.96     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
